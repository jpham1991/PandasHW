# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
schools = os.path.join("Resources", "schools_complete.csv")
students = os.path.join("Resources", "students_complete.csv")

schools_df = pd.read_csv(schools)
students_df = pd.read_csv(students)

# %%
schools_df.head()
# Out:
#    School ID                   name      type  size   budget  \
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500
#
#   Per Student Budget Average Math Score Average Reading Score % Passing Math  \
# 0             655.00              76.63                 81.18          88.86
# 1             639.00              76.71                 81.16          88.44
# 2             600.00              83.36                 83.73         100.00
# 3             652.00              77.29                 80.93          89.08
# 4             625.00              83.35                 83.82         100.00
#
#   % Passing Reading Overall Passing Rate
# 0            100.00                94.43
# 1            100.00                94.22
# ...

# %%
school_names = students_df['school']
students_df.head()
# Out:
#    Student ID               name gender grade             school  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
total_schools = schools_df["name"].count()
total_schools
# Out:
# 15

# %%
total_students = students_df["name"].count()
total_students
# Out:
# 39170

# %%
total_budget = schools_df["budget"].sum()
total_budget
# Out:
# 24649428

# %%
average_math = students_df["math_score"].mean()
average_math
# Out:
# 78.98537145774827

# %%
average_reading = students_df["reading_score"].mean()
average_reading
# Out:
# 81.87784018381414

# %%
pass_math = students_df[(students_df['math_score']>=60)]
pass_math
# Out:
#        Student ID                 name gender grade              school  \
# 0               0         Paul Bradley      M   9th   Huang High School
# 1               1         Victor Smith      M  12th   Huang High School
# 2               2      Kevin Rodriguez      M  12th   Huang High School
# 4               4           Bonnie Ray      F   9th   Huang High School
# 5               5        Bryan Miranda      M   9th   Huang High School
# 6               6        Sheena Carter      F  11th   Huang High School
# 7               7         Nicole Baker      F  12th   Huang High School
# 8               8         Michael Roth      M  10th   Huang High School
# 9               9       Matthew Greene      M  10th   Huang High School
# 10             10     Andrew Alexander      M  10th   Huang High School
# 11             11        Daniel Cooper      M  10th   Huang High School
# 12             12      Brittney Walker      F   9th   Huang High School
# ...

# %%
pass_math_ct = pass_math['name'].count()
pass_math_ct
# Out:
# 36211

# %%
per_pass_math = (pass_math_ct/total_students)*100
per_pass_math
# Out:
# 92.445749297932096

# %%
pass_reading = students_df[(students_df['reading_score']>=60)]
pass_reading
# Out:
#        Student ID                 name gender grade              school  \
# 0               0         Paul Bradley      M   9th   Huang High School
# 1               1         Victor Smith      M  12th   Huang High School
# 2               2      Kevin Rodriguez      M  12th   Huang High School
# 3               3    Dr. Richard Scott      M  12th   Huang High School
# 4               4           Bonnie Ray      F   9th   Huang High School
# 5               5        Bryan Miranda      M   9th   Huang High School
# 6               6        Sheena Carter      F  11th   Huang High School
# 7               7         Nicole Baker      F  12th   Huang High School
# 8               8         Michael Roth      M  10th   Huang High School
# 9               9       Matthew Greene      M  10th   Huang High School
# 10             10     Andrew Alexander      M  10th   Huang High School
# 11             11        Daniel Cooper      M  10th   Huang High School
# ...

# %%
pass_read_ct = pass_reading['name'].count()
pass_read_ct
# Out:
# 39170

# %%
per_pass_read = ((pass_read_ct/total_students)*100)
per_pass_read
# Out:
# 100.0

# %%
#overall_pass = ((per_pass_read + per_pass_math)/2)
#ds_df["Overall Passing Rate"] = pd.to_numeric(ds_df["Overall Passing Rate"])
#overall_pass = 96.22
overall_pass
# Out:
# 96

# %%
ds_titles = ["Total Schools", "Total Students", "Total Budget", "Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "Overall Passing Rate"]
ds_info = {"Total Schools": [total_schools], "Total Students": [total_students], "Total Budget": [total_budget], "Average Math Score": [average_math], "Average Reading Score": [average_reading], "% Passing Math": [per_pass_math], "% Passing Reading": [per_pass_read], "Overall Passing": [overall_pass]}
ds_df = pd.DataFrame(ds_info, columns=[ds_titles])

# %%
#ds = pd.DataFrame(columns=[ds_titles], index=[ds_info])
#ds = pd.DataFrame(index=[ds_titles], [ds_info])
#ds
ds_df["Total Budget"] = ds_df["Total Budget"].map("$ {:,.1f}".format)
ds_df["Average Math Score"] = ds_df["Average Math Score"].map("{:,.1f}".format)
ds_df["Average Reading Score"] = ds_df["Average Reading Score"].map("{:,.1f}".format)
ds_df["% Passing Math"] = ds_df["% Passing Math"].map("{:,.1f}".format)
ds_df["Total Students"] = ds_df["Total Students"].map("{:,.0f}".format)
ds_df
# Out:
#    Total Schools Total Students    Total Budget Average Math Score  \
# 0             15         39,170  $ 24,649,428.0               79.0
#
#   Average Reading Score % Passing Math  % Passing Reading Overall Passing Rate
# 0                  81.9           92.4              100.0                  NaN

# %%
#ds_df["Overall Passing Rate"] = pd.to_numeric(ds_df["Overall Passing Rate"])
ds_df["Overall Passing Rate"] = "96.22"
ds_df
# Out:
#    Total Schools Total Students    Total Budget Average Math Score  \
# 0             15         39,170  $ 24,649,428.0               79.0
#
#   Average Reading Score % Passing Math  % Passing Reading Overall Passing Rate
# 0                  81.9           92.4              100.0                96.22

# %%
size = schools_df["size"].value_counts()
size
# Out:
# 3999    1
# 2949    1
# 1468    1
# 4635    1
# 4761    1
# 427     1
# 962     1
# 2739    1
# 4976    1
# 2283    1
# 1800    1
# 2917    1
# 1635    1
# 1858    1
# 1761    1
# Name: size, dtype: int64

# %%
Huang = students_df.loc[students_df['school'] == "Huang High School",:].copy()
Huang
# Out:
#       Student ID                 name gender grade             school  \
# 0              0         Paul Bradley      M   9th  Huang High School
# 1              1         Victor Smith      M  12th  Huang High School
# 2              2      Kevin Rodriguez      M  12th  Huang High School
# 3              3    Dr. Richard Scott      M  12th  Huang High School
# 4              4           Bonnie Ray      F   9th  Huang High School
# 5              5        Bryan Miranda      M   9th  Huang High School
# 6              6        Sheena Carter      F  11th  Huang High School
# 7              7         Nicole Baker      F  12th  Huang High School
# 8              8         Michael Roth      M  10th  Huang High School
# 9              9       Matthew Greene      M  10th  Huang High School
# 10            10     Andrew Alexander      M  10th  Huang High School
# 11            11        Daniel Cooper      M  10th  Huang High School
# ...

# %%
Fig = students_df.loc[students_df['school'] == "Figueroa High School",:].copy()
Fig
# Out:
#       Student ID                     name gender grade                school  \
# 2917        2917               Amy Jacobs      F  10th  Figueroa High School
# 2918        2918          Nathan Campbell      M  12th  Figueroa High School
# 2919        2919          Randall Stewart      M  12th  Figueroa High School
# 2920        2920           Jennifer Brown      F   9th  Figueroa High School
# 2921        2921             Denise Lopez      F  10th  Figueroa High School
# 2922        2922      Amanda Hamilton DDS      F   9th  Figueroa High School
# 2923        2923             Anthony Pace      M  10th  Figueroa High School
# 2924        2924           Anthony Haynes      M  12th  Figueroa High School
# 2925        2925          Natasha Maxwell      F   9th  Figueroa High School
# 2926        2926           Christine Mann      F   9th  Figueroa High School
# 2927        2927              Jodi Taylor      F  10th  Figueroa High School
# ...

# %%
Shelton = students_df.loc[students_df['school'] == "Shelton High School",:].copy()
Shelton
# Out:
#       Student ID                 name gender grade               school  \
# 5866        5866     Jamie Montgomery      F  12th  Shelton High School
# 5867        5867     Shannon Phillips      F  10th  Shelton High School
# 5868        5868          Todd Barber      M  11th  Shelton High School
# 5869        5869         Desiree King      F  12th  Shelton High School
# 5870        5870      Melissa Roberts      F  10th  Shelton High School
# 5871        5871        Earl Martinez      M   9th  Shelton High School
# 5872        5872          Jose Willis      M  11th  Shelton High School
# 5873        5873          Andrew Shea      M   9th  Shelton High School
# 5874        5874      Catherine Price      F  12th  Shelton High School
# 5875        5875       Matthew Fowler      M   9th  Shelton High School
# 5876        5876        Keith Preston      M  12th  Shelton High School
# 5877        5877          Mark Wilson      M  12th  Shelton High School
# ...

# %%
Hern = students_df.loc[students_df['school'] == "Hernandez High School",:].copy()
Hern
# Out:
#        Student ID                  name gender grade                 school  \
# 7627         7627         Russell Davis      M  10th  Hernandez High School
# 7628         7628        Timothy Walker      M  12th  Hernandez High School
# 7629         7629        Katie Johnston      F  12th  Hernandez High School
# 7630         7630        Joann Oconnell      F  12th  Hernandez High School
# 7631         7631       Sarah Alexander      F  10th  Hernandez High School
# 7632         7632      Kathleen Nichols      F  10th  Hernandez High School
# 7633         7633       Lawrence Martin      M  10th  Hernandez High School
# 7634         7634        Laura Callahan      F  12th  Hernandez High School
# 7635         7635     Natalie Rivera MD      F   9th  Hernandez High School
# 7636         7636             John Hunt      M   9th  Hernandez High School
# 7637         7637           Erika Cross      F  10th  Hernandez High School
# ...

# %%
Griff = students_df.loc[students_df['school'] == "Griffin High School",:].copy()
Griff
# Out:
#        Student ID                name gender grade               school  \
# 12262       12262      Heather Wright      F  11th  Griffin High School
# 12263       12263   Elizabeth Goodwin      F  10th  Griffin High School
# 12264       12264       Michelle Wong      F   9th  Griffin High School
# 12265       12265       Scott Roth MD      M  11th  Griffin High School
# 12266       12266        Billy Wilson      M  12th  Griffin High School
# 12267       12267         Robert Lane      M  11th  Griffin High School
# 12268       12268           Lisa Long      F  10th  Griffin High School
# 12269       12269         Scott Brown      M  10th  Griffin High School
# 12270       12270        Thomas Smith      M   9th  Griffin High School
# 12271       12271        Linda Medina      F  10th  Griffin High School
# 12272       12272     Katrina Johnson      F  12th  Griffin High School
# 12273       12273        Taylor Hurst      F  11th  Griffin High School
# ...

# %%
Wilson = students_df.loc[students_df['school'] == "Wilson High School",:].copy()
Wilson
# Out:
#        Student ID                    name gender grade              school  \
# 13730       13730          Kelli Anderson      F  10th  Wilson High School
# 13731       13731         Russell Ramirez      M  10th  Wilson High School
# 13732       13732             Eric Butler      M  10th  Wilson High School
# 13733       13733             Warren Kerr      M  11th  Wilson High School
# 13734       13734               Gail Hall      F   9th  Wilson High School
# 13735       13735          Angela Walters      F   9th  Wilson High School
# 13736       13736           Brandi Davila      F  11th  Wilson High School
# 13737       13737        Natasha Williams      F  10th  Wilson High School
# 13738       13738             James Owens      M  12th  Wilson High School
# 13739       13739           Tamara Torres      F   9th  Wilson High School
# 13740       13740                Emma Day      F   9th  Wilson High School
# ...

# %%
Cab = students_df.loc[students_df['school'] == "Cabrera High School",:].copy()
Cab
# Out:
#        Student ID                     name gender grade               school  \
# 16013       16013             Olivia Short      F  11th  Cabrera High School
# 16014       16014              Kerry Jones      F   9th  Cabrera High School
# 16015       16015            Bruce Jackson      M  12th  Cabrera High School
# 16016       16016                Amy Green      F  12th  Cabrera High School
# 16017       16017            Melanie Mason      F  12th  Cabrera High School
# 16018       16018              Donna Knapp      F  10th  Cabrera High School
# 16019       16019            Dylan Elliott      M  12th  Cabrera High School
# 16020       16020            Renee Randall      F  10th  Cabrera High School
# 16021       16021         Dennis Castaneda      M  11th  Cabrera High School
# 16022       16022          Nicole Petersen      F   9th  Cabrera High School
# 16023       16023            Michael Curry      M  10th  Cabrera High School
# ...

# %%
Bailey = students_df.loc[students_df['school'] == "Bailey High School",:].copy()
Bailey
# Out:
#        Student ID                 name gender grade              school  \
# 17871       17871         Blake Martin      M   9th  Bailey High School
# 17872       17872         Kathryn Kane      F  12th  Bailey High School
# 17873       17873         Richard Haas      M  11th  Bailey High School
# 17874       17874          Frank Marsh      M   9th  Bailey High School
# 17875       17875  Charles Goodman Jr.      M   9th  Bailey High School
# 17876       17876         James Burton      M  11th  Bailey High School
# 17877       17877         James Rogers      M  11th  Bailey High School
# 17878       17878            Wendy Fox      F  12th  Bailey High School
# 17879       17879         Lori Lambert      F  11th  Bailey High School
# 17880       17880          Aaron Moyer      M   9th  Bailey High School
# 17881       17881       Antonio Foster      M  10th  Bailey High School
# 17882       17882         Michael Dean      M   9th  Bailey High School
# ...

# %%
Holden = students_df.loc[students_df['school'] == "Holden High School",:].copy()
Holden
# Out:
#        Student ID                 name gender grade              school  \
# 22847       22847     Daniel Rodriguez      M  11th  Holden High School
# 22848       22848        Bryan Perkins      M   9th  Holden High School
# 22849       22849         Scott Holder      M   9th  Holden High School
# 22850       22850         Troy Jackson      M  11th  Holden High School
# 22851       22851        William Gomez      M   9th  Holden High School
# 22852       22852        Lance Lindsey      M   9th  Holden High School
# 22853       22853      Alice Hernandez      F  11th  Holden High School
# 22854       22854       Nicole Baldwin      F  11th  Holden High School
# 22855       22855     Shelly Robertson      F   9th  Holden High School
# 22856       22856      Anthony Jackson      M   9th  Holden High School
# 22857       22857         Darren Gross      M  11th  Holden High School
# 22858       22858   Stephanie Jennings      F  10th  Holden High School
# ...

# %%
Pena = students_df.loc[students_df['school'] == "Pena High School",:].copy()
Pena
# Out:
#        Student ID                  name gender grade            school  \
# 23274       23274            Alec Davis      M   9th  Pena High School
# 23275       23275         Michael Meyer      M  10th  Pena High School
# 23276       23276      Donald Gutierrez      M  11th  Pena High School
# 23277       23277         Travis Chavez      M  11th  Pena High School
# 23278       23278           Sheena Ball      F  12th  Pena High School
# 23279       23279          Jenna Weaver      F   9th  Pena High School
# 23280       23280     Richard Alexander      M  11th  Pena High School
# 23281       23281       Chris Underwood      M  12th  Pena High School
# 23282       23282     Jacqueline Hebert      F  12th  Pena High School
# 23283       23283       Cheyenne Garcia      F  11th  Pena High School
# 23284       23284           Lance Davis      M  12th  Pena High School
# 23285       23285       Joshua Johnston      M   9th  Pena High School
# ...

# %%
Wright = students_df.loc[students_df['school'] == "Wright High School",:].copy()
Wright
# Out:
#        Student ID                name gender grade              school  \
# 24236       24236       Aaron Johnson      M  10th  Wright High School
# 24237       24237   Kimberly Hamilton      F  10th  Wright High School
# 24238       24238        Ashley Johns      F  10th  Wright High School
# 24239       24239   Stephanie Donovan      F  10th  Wright High School
# 24240       24240      Cynthia Guzman      F  11th  Wright High School
# 24241       24241        Mario Daniel      M  10th  Wright High School
# 24242       24242        Debbie Perry      F  11th  Wright High School
# 24243       24243       Anthony Weiss      M  10th  Wright High School
# 24244       24244           Amy Hanna      F  11th  Wright High School
# 24245       24245       Eric Espinoza      M   9th  Wright High School
# 24246       24246      Melanie Thomas      F  10th  Wright High School
# 24247       24247     Shannon Barajas      F  10th  Wright High School
# ...

# %%
Rod = students_df.loc[students_df['school'] == "Rodriguez High School",:].copy()
Rod
# Out:
#        Student ID               name gender grade                 school  \
# 26036       26036     Sherry Jenkins      F  11th  Rodriguez High School
# 26037       26037  Kimberly Calderon      F  10th  Rodriguez High School
# 26038       26038      William Brady      M  11th  Rodriguez High School
# 26039       26039      Jacob Padilla      M  11th  Rodriguez High School
# 26040       26040    Paula Maldonado      F  10th  Rodriguez High School
# 26041       26041   Patricia Escobar      F  12th  Rodriguez High School
# 26042       26042     Becky Castillo      F  11th  Rodriguez High School
# 26043       26043      Tamara Morris      F  10th  Rodriguez High School
# 26044       26044        Brian Smith      M   9th  Rodriguez High School
# 26045       26045   Katelyn Valencia      F  12th  Rodriguez High School
# 26046       26046           Gary Orr      M   9th  Rodriguez High School
# 26047       26047     Melissa Lowery      F   9th  Rodriguez High School
# ...

# %%
John = students_df.loc[students_df['school'] == "Johnson High School",:].copy()
John
# Out:
#        Student ID                 name gender grade               school  \
# 30035       30035           Lisa Casey      F  12th  Johnson High School
# 30036       30036        Jessica Lopez      F   9th  Johnson High School
# 30037       30037         Anna Wilkins      F  11th  Johnson High School
# 30038       30038         Andrew Smith      M   9th  Johnson High School
# 30039       30039       Robert Allison      M  11th  Johnson High School
# 30040       30040        Andrew Wilson      M  11th  Johnson High School
# 30041       30041       Kevin Odonnell      M   9th  Johnson High School
# 30042       30042     Courtney Ramirez      F  10th  Johnson High School
# 30043       30043        Walter Turner      M   9th  Johnson High School
# 30044       30044            Kayla Day      F  11th  Johnson High School
# 30045       30045      Tamara Mitchell      F  12th  Johnson High School
# 30046       30046        Martin Hudson      M  12th  Johnson High School
# ...

# %%
Ford = students_df.loc[students_df['school'] == "Ford High School",:].copy()
Ford
# Out:
#        Student ID                name gender grade            school  \
# 34796       34796     Michael Mercado      M   9th  Ford High School
# 34797       34797        Stephen Wolf      M  11th  Ford High School
# 34798       34798       Bonnie Hughes      F  12th  Ford High School
# 34799       34799       Melissa Smith      F  11th  Ford High School
# 34800       34800      Brian Mitchell      M  10th  Ford High School
# 34801       34801   Mr. William Scott      M   9th  Ford High School
# 34802       34802      Stephen Taylor      M  11th  Ford High School
# 34803       34803          Steven Lee      M   9th  Ford High School
# 34804       34804    Candace Campbell      F  11th  Ford High School
# 34805       34805    Veronica English      F   9th  Ford High School
# 34806       34806    Crystal Sandoval      F  11th  Ford High School
# 34807       34807  Christopher Garcia      M   9th  Ford High School
# 34808       34808      Tamara Daniels      F  12th  Ford High School
# ...

# %%
Thom = students_df.loc[students_df['school'] == "Thomas High School",:].copy()
Thom
# Out:
#        Student ID                  name gender grade              school  \
# 37535       37535            Norma Mata      F  10th  Thomas High School
# 37536       37536           Cody Miller      M  11th  Thomas High School
# 37537       37537           Erik Snyder      M   9th  Thomas High School
# 37538       37538        Tanya Martinez      F   9th  Thomas High School
# 37539       37539         Noah Erickson      M   9th  Thomas High School
# 37540       37540          Austin Meyer      M   9th  Thomas High School
# 37541       37541          Eric Stevens      M  10th  Thomas High School
# 37542       37542     Elizabeth Bennett      F  11th  Thomas High School
# 37543       37543       Madison Hampton      F   9th  Thomas High School
# 37544       37544     Jacqueline Harris      F  10th  Thomas High School
# 37545       37545      Christopher Shaw      M  10th  Thomas High School
# 37546       37546      Steven Hoover MD      M  12th  Thomas High School
# ...

# %%
HMath = Huang['math_score'].mean()
FigMath = Fig['math_score'].mean()
SheltonMath = Shelton['math_score'].mean()
HernMath = Hern['math_score'].mean()
GriffinMath = Griff['math_score'].mean()
WilsonMath = Wilson['math_score'].mean()
CabMath = Cab['math_score'].mean()
BaileyMath = Bailey['math_score'].mean()
HoldenMath = Holden['math_score'].mean()
PenaMath = Pena['math_score'].mean()
WrightMath = Wright['math_score'].mean()
RodMath = Rod['math_score'].mean()
JohnMath = John['math_score'].mean()
FordMath = Ford['math_score'].mean()
ThomMath = Thom['math_score'].mean()

# %%
all_math_avg = [HMath, FigMath, SheltonMath, HernMath, GriffinMath, WilsonMath, CabMath, BaileyMath, HoldenMath, PenaMath, WrightMath, RodMath, JohnMath, FordMath, ThomMath]

# %%
all_math_avg
# Out:
# [76.62941378128214,
#  76.71176670057646,
#  83.3594548551959,
#  77.28975188781014,
#  83.35149863760218,
#  83.2742006132282,
#  83.06189451022605,
#  77.04843247588424,
#  83.80327868852459,
#  83.83991683991684,
#  83.68222222222222,
#  76.84271067766942,
#  77.07246376811594,
#  77.10259218692954,
#  83.4183486238532]

# %%
HRead = Huang['reading_score'].mean()
FigRead = Fig['reading_score'].mean()
SheltonRead = Shelton['reading_score'].mean()
HernRead = Hern['reading_score'].mean()
GriffinRead = Griff['reading_score'].mean()
WilsonRead = Wilson['reading_score'].mean()
CabRead = Cab['reading_score'].mean()
BaileyRead = Bailey['reading_score'].mean()
HoldenRead = Holden['reading_score'].mean()
PenaRead = Pena['reading_score'].mean()
WrightRead = Wright['reading_score'].mean()
RodRead = Rod['reading_score'].mean()
JohnRead = John['reading_score'].mean()
FordRead = Ford['reading_score'].mean()
ThomRead = Thom['reading_score'].mean()

# %%
all_read_avg = [HRead, FigRead, SheltonRead, HernRead, GriffinRead, WilsonRead, CabRead, BaileyRead, HoldenRead, PenaRead, WrightRead, RodRead, JohnRead, FordRead, ThomRead]

# %%
HMathPa = Huang[(Huang['math_score']>=60)]
HMathP = HMathPa["name"].count()
FigMathPa = Fig[(Fig['math_score']>=60)]
SheltonMathPa = Shelton[(Shelton['math_score']>=60)]
HernMathPa = Hern[(Hern['math_score']>=60)]
GriffinMathPa = Griff[(Griff['math_score']>=60)]
WilsonMathPa = Wilson[(Wilson['math_score']>=60)]
CabMathPa = Cab[(Cab['math_score']>=60)]
BaileyMathPa = Bailey[(Bailey['math_score']>=60)]
HoldenMathPa = Holden[(Holden['math_score']>=60)]
PenaMathPa = Pena[(Pena['math_score']>=60)]
WrightMathPa = Wright[(Wright['math_score']>=60)]
RodMathPa = Rod[(Rod['math_score']>=60)]
JohnMathPa = John[(John['math_score']>=60)]
FordMathPa = Ford[(Ford['math_score']>=60)]
ThomMathPa = Thom[(Thom['math_score']>=60)]

FigMathP = FigMathPa["name"].count()
SheltonMathP = SheltonMathPa["name"].count()
HernMathP = HernMathPa["name"].count()
GriffinMathP = GriffinMathPa["name"].count()
WilsonMathP = WilsonMathPa["name"].count()
CabMathP = CabMathPa["name"].count()
BaileyMathP = BaileyMathPa["name"].count()
HoldenMathP = HoldenMathPa["name"].count()
PenaMathP = PenaMathPa["name"].count()
WrightMathP = WrightMathPa["name"].count()
RodMathP = RodMathPa["name"].count()
JohnMathP = JohnMathPa["name"].count()
FordMathP = FordMathPa["name"].count()
ThomMathP = ThomMathPa["name"].count()
all_pass_math = [HMathP, FigMathP, SheltonMathP, HernMathP, GriffinMathP, WilsonMathP, CabMathP, BaileyMathP, HoldenMathP, PenaMathP, WrightMathP, RodMathP, JohnMathP, FordMathP, ThomMathP]

all_pass_math
# Out:
# [2592,
#  2608,
#  1761,
#  4129,
#  1468,
#  2283,
#  1858,
#  4455,
#  427,
#  962,
#  1800,
#  3541,
#  4246,
#  2446,
#  1635]

# %%
HReadPa = Huang[(Huang['reading_score']>=60)]
HReadP = HReadPa["name"].count()
FigReadPa = Fig[(Fig['reading_score']>=60)]
SheltonReadPa = Shelton[(Shelton['reading_score']>=60)]
HernReadPa = Hern[(Hern['reading_score']>=60)]
GriffinReadPa = Griff[(Griff['reading_score']>=60)]
WilsonReadPa = Wilson[(Wilson['reading_score']>=60)]
CabReadPa = Cab[(Cab['reading_score']>=60)]
BaileyReadPa = Bailey[(Bailey['reading_score']>=60)]
HoldenReadPa = Holden[(Holden['reading_score']>=60)]
PenaReadPa = Pena[(Pena['reading_score']>=60)]
WrightReadPa = Wright[(Wright['reading_score']>=60)]
RodReadPa = Rod[(Rod['reading_score']>=60)]
JohnReadPa = John[(John['reading_score']>=60)]
FordReadPa = Ford[(Ford['reading_score']>=60)]
ThomReadPa = Thom[(Thom['reading_score']>=60)]

FigReadP = FigReadPa["name"].count()
SheltonReadP = SheltonReadPa["name"].count()
HernReadP = HernReadPa["name"].count()
GriffinReadP = GriffinReadPa["name"].count()
WilsonReadP = WilsonReadPa["name"].count()
CabReadP = CabReadPa["name"].count()
BaileyReadP = BaileyReadPa["name"].count()
HoldenReadP = HoldenReadPa["name"].count()
PenaReadP = PenaReadPa["name"].count()
WrightReadP = WrightReadPa["name"].count()
RodReadP = RodReadPa["name"].count()
JohnReadP = JohnReadPa["name"].count()
FordReadP = FordReadPa["name"].count()
ThomReadP = ThomReadPa["name"].count()
all_pass_read = [HReadP, FigReadP, SheltonReadP, HernReadP, GriffinReadP, WilsonReadP, CabReadP, BaileyReadP, HoldenReadP, PenaReadP, WrightReadP, RodReadP, JohnReadP, FordReadP, ThomReadP]

all_pass_read
# Out:
# [2917,
#  2949,
#  1761,
#  4635,
#  1468,
#  2283,
#  1858,
#  4976,
#  427,
#  962,
#  1800,
#  3999,
#  4761,
#  2739,
#  1635]

# %%
HOM = HMathPa["name"].count()
FigOM = FigMathPa["name"].count()
SheltonOM = SheltonMathPa["name"].count()
HernOM = HernMathPa["name"].count()
GriffinOM = GriffinMathPa["name"].count()
WilsonOM = WilsonMathPa["name"].count()
CabOM = CabMathPa["name"].count()
BaileyOM = BaileyMathPa["name"].count()
HoldenOM = HoldenMathPa["name"].count()
PenaOM = PenaMathPa["name"].count()
WrightOM = WrightMathPa["name"].count()
RodOM = RodMathPa["name"].count()
JohnOM = JohnMathPa["name"].count()
FordOM = FordMathPa["name"].count()
ThomOM = ThomMathPa["name"].count()
OMPass = [HOM, FigOM, SheltonOM, HernOM, GriffinOM, WilsonOM, CabOM, BaileyOM, HoldenOM, PenaOM, WrightOM, RodOM, JohnOM, FordOM, ThomOM]


HReadPO = HReadPa["name"].count()
FigReadPO = FigReadPa["name"].count()
SheltonReadPO = SheltonReadPa["name"].count()
HernReadPO = HernReadPa["name"].count()
GriffinReadPO = GriffinReadPa["name"].count()
WilsonReadPO = WilsonReadPa["name"].count()
CabReadPO = CabReadPa["name"].count()
BaileyReadPO = BaileyReadPa["name"].count()
HoldenReadPO = HoldenReadPa["name"].count()
PenaReadPO = PenaReadPa["name"].count()
WrightReadPO = WrightReadPa["name"].count()
RodReadPO = RodReadPa["name"].count()
JohnReadPO = JohnReadPa["name"].count()
FordReadPO = FordReadPa["name"].count()
ThomReadPO = ThomReadPa["name"].count()
ORPass = [HReadPO, FigReadPO, SheltonReadPO, HernReadPO, GriffinReadPO, WilsonReadPO, CabReadPO, BaileyReadPO, HoldenReadPO, PenaReadPO, WrightReadPO, RodReadPO, JohnReadPO, FordReadPO, ThomReadPO]

Overa = OMPass/All_Schools['size'] 
Overb = ORPass/All_Schools['size']
Overc = ((Overa + Overb)/2)*100
Overc
# Out:
# 0      94.429208
# 1      94.218379
# 2     100.000000
# 3      94.541532
# 4     100.000000
# 5     100.000000
# 6     100.000000
# 7      94.764871
# 8     100.000000
# 9     100.000000
# 10    100.000000
# 11     94.273568
# 12     94.591472
# 13     94.651333
# 14    100.000000
# Name: size, dtype: float64

# %%
#per_student_budget = (total_school_budget/students_by_school_df)
#per_student_budget
ss_titles = ["School Type", "Total Students", "Total School Budget", "Per Student Budget", "Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing Rate"]
ss_info = {"School Type": [school_type]}
#School_summary = pd.DataFrame(index=[school_names],columns=[ss_titles])
All_Schools = pd.DataFrame(schools_df)
All_Schools["Per Student Budget"] = All_Schools['budget']/All_Schools['size']
All_Schools["Average Math Score"] = all_math_avg
All_Schools["Average Math Score"] = All_Schools["Average Math Score"].map("{:,.2f}".format)
All_Schools["Per Student Budget"] = All_Schools["Per Student Budget"].map("{:,.2f}".format)
All_Schools["Average Reading Score"] = all_read_avg
All_Schools["Average Reading Score"] = All_Schools["Average Reading Score"].map("{:,.2f}".format)
All_Schools["% Passing Math"] = (all_pass_math/All_Schools['size'])*100
All_Schools["% Passing Math"] = All_Schools["% Passing Math"].map("{:,.2f}".format)
All_Schools["% Passing Reading"] = (all_pass_read/All_Schools['size'])*100
All_Schools["% Passing Reading"] = All_Schools["% Passing Reading"].map("{:,.2f}".format)

All_Schools["Overall Passing Rate"] = Overc

All_Schools["Overall Passing Rate"] = All_Schools["Overall Passing Rate"].map("{:,.2f}".format)
All_Schools
# Out:
#     School ID                   name      type  size   budget  \
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
School_Summary = All_Schools

# %%
School_Summary
# Out:
#     School ID                   name      type  size   budget  \
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
School_Summary = School_Summary.rename(columns={"size" : "Total Students"})
School_Summary = School_Summary.rename(columns={"name" : "School Name"})
School_Summary = School_Summary.rename(columns={"budget" : "Total School Budget"})
School_Summary = School_Summary.rename(columns={"type" : "School Type"})
School_Summary = School_Summary.drop("School ID",1)
School_Summary
# Out:
# ------------------------------------------------------------------------
# ValueError                             Traceback (most recent call last)
# <ipython-input-700-6c08b4ab590b> in <module>()
#       3 School_Summary = School_Summary.rename(columns={"budget" : "Total School Budget"})
#       4 School_Summary = School_Summary.rename(columns={"type" : "School Type"})
# ----> 5 School_Summary = School_Summary.drop("School ID",1)
#       6 School_Summary
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
# ...

# %%
School_Summary
# Out:
#               School Name School Type  Total Students  Total School Budget  \
# 0       Huang High School    District            2917              1910635
# 1    Figueroa High School    District            2949              1884411
# 2     Shelton High School     Charter            1761              1056600
# 3   Hernandez High School    District            4635              3022020
# 4     Griffin High School     Charter            1468               917500
# 5      Wilson High School     Charter            2283              1319574
# 6     Cabrera High School     Charter            1858              1081356
# 7      Bailey High School    District            4976              3124928
# 8      Holden High School     Charter             427               248087
# 9        Pena High School     Charter             962               585858
# 10     Wright High School     Charter            1800              1049400
# ...

# %%
#Top_Peform = School_Summary[(School_Summary['% Passing Reading']==100) & (School_Summary['% Passing Math']==100)] 
#Top_Perform.head()
Top_Perform = School_Summary.sort_values('Average Math Score', ascending=False)
Top_Perform_5 = Top_Perform.head(5)
Top_Perform_5
# Out:
#             School Name School Type  Total Students  Total School Budget  \
# 9      Pena High School     Charter             962               585858
# 8    Holden High School     Charter             427               248087
# 10   Wright High School     Charter            1800              1049400
# 14   Thomas High School     Charter            1635              1043130
# 2   Shelton High School     Charter            1761              1056600
#
#    Per Student Budget Average Math Score Average Reading Score % Passing Math  \
# 9              609.00              83.84                 84.04         100.00
# 8              581.00              83.80                 83.81         100.00
# 10             583.00              83.68                 83.95         100.00
# 14             638.00              83.42                 83.85         100.00
# 2              600.00              83.36                 83.73         100.00
#
#    % Passing Reading Overall Passing Rate
# ...

# %%
Bottom = School_Summary.sort_values('Overall Passing Rate', ascending=False)
Bottom_5 = Bottom.head(5)
Bottom_5
# Out:
#               School Name School Type  Total Students  Total School Budget  \
# 7      Bailey High School    District            4976              3124928
# 13       Ford High School    District            2739              1763916
# 12    Johnson High School    District            4761              3094650
# 3   Hernandez High School    District            4635              3022020
# 0       Huang High School    District            2917              1910635
#
#    Per Student Budget Average Math Score Average Reading Score % Passing Math  \
# 7              628.00              77.05                 81.03          89.53
# 13             644.00              77.10                 80.75          89.30
# 12             650.00              77.07                 80.97          89.18
# 3              652.00              77.29                 80.93          89.08
# 0              655.00              76.63                 81.18          88.86
#
#    % Passing Reading Overall Passing Rate
# ...

# %%
Grades = students_df["grade"].value_counts()

# %%
Data_frame = students_df[["school","grade","reading_score"]]
Huang_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Huang High School")]
#mHuang_grade9 = Huang_grade9.median()
Fig_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Figueroa High School")]
Shelton_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Shelton High School")]
Hernandez_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Hernandez High School")]
Griffin_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Griffin High School")]
Wilson_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Wilson High School")]
Cab_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Cabrera High School")]
Bailey_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Bailey High School")]
Holden_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Holden High School")]
Pena_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Pena High School")]
Wright_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Wright High School")]
Rod_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Rodriguez High School")]
John_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Johnson High School")]
Ford_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Ford High School")]
Thomas_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Thomas High School")]


Huang_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Huang High School")]
Fig_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Figueroa High School")]
Shelton_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Shelton High School")]
Hernandez_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Hernandez High School")]
Griffin_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Griffin High School")]
Wilson_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Wilson High School")]
Cab_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Cabrera High School")]
Bailey_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Bailey High School")]
Holden_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Holden High School")]
Pena_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Pena High School")]
Wright_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Wright High School")]
Rod_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Rodriguez High School")]
John_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Johnson High School")]
Ford_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Ford High School")]
Thomas_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Thomas High School")]



Huang_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Huang High School")]
Fig_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Figueroa High School")]
Shelton_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Shelton High School")]
Hernandez_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Hernandez High School")]
Griffin_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Griffin High School")]
Wilson_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Wilson High School")]
Cab_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Cabrera High School")]
Bailey_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Bailey High School")]
Holden_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Holden High School")]
Pena_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Pena High School")]
Wright_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Wright High School")]
Rod_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Rodriguez High School")]
John_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Johnson High School")]
Ford_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Ford High School")]
Thomas_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Thomas High School")]

Huang_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Huang High School")]
Fig_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Figueroa High School")]
Shelton_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Shelton High School")]
Hernandez_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Hernandez High School")]
Griffin_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Griffin High School")]
Wilson_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Wilson High School")]
Cab_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Cabrera High School")]
Bailey_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Bailey High School")]
Holden_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Holden High School")]
Pena_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Pena High School")]
Wright_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Wright High School")]
Rod_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Rodriguez High School")]
John_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Johnson High School")]
Ford_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Ford High School")]
Thomas_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Thomas High School")]

#grade9 = [(Huang_grade9), Fig_grade9, Shelton_grade9, Hernandez_grade9, Griffin_grade9, Wilson_grade9, Cab_grade9, Bailey_grade9, Holden_grade9, Pena_grade9, Wright_grade9, Rod_grade9, John_grade9, Ford_grade9, Thomas_grade9]
MHuang_grade9 = Huang_grade9['reading_score'].median()
MFig_grade9 = Fig_grade9['reading_score'].median()
MShelton_grade9 = Shelton_grade9['reading_score'].median()
MHernandez_grade9 = Hernandez_grade9['reading_score'].median()
MGriffin_grade9 = Griffin_grade9['reading_score'].median()
MWilson_grade9 = Wilson_grade9['reading_score'].median()
MCab_grade9 = Cab_grade9['reading_score'].median()
MBailey_grade9 = Bailey_grade9['reading_score'].median()
MHolden_grade9 = Holden_grade9['reading_score'].median()
MPena_grade9 = Pena_grade9['reading_score'].median()
MWright_grade9 = Wright_grade9['reading_score'].median()
MRod_grade9 = Rod_grade9['reading_score'].median()
MJohn_grade9 = John_grade9['reading_score'].median()
MFord_grade9 = Ford_grade9['reading_score'].median()
MThomas_grade9 = Thomas_grade9['reading_score'].median()

MHuang_grade10 = Huang_grade10['reading_score'].median()
MFig_grade10 = Fig_grade10['reading_score'].median()
MShelton_grade10 = Shelton_grade10['reading_score'].median()
MHernandez_grade10 = Hernandez_grade10['reading_score'].median()
MGriffin_grade10 = Griffin_grade10['reading_score'].median()
MWilson_grade10 = Wilson_grade10['reading_score'].median()
MCab_grade10 = Cab_grade10['reading_score'].median()
MBailey_grade10 = Bailey_grade10['reading_score'].median()
MHolden_grade10 = Holden_grade10['reading_score'].median()
MPena_grade10 = Pena_grade10['reading_score'].median()
MWright_grade10 = Wright_grade10['reading_score'].median()
MRod_grade10 = Rod_grade10['reading_score'].median()
MJohn_grade10 = John_grade10['reading_score'].median()
MFord_grade10 = Ford_grade10['reading_score'].median()
MThomas_grade10 = Thomas_grade10['reading_score'].median()

MHuang_grade11 = Huang_grade11['reading_score'].median()
MFig_grade11 = Fig_grade11['reading_score'].median()
MShelton_grade11 = Shelton_grade11['reading_score'].median()
MHernandez_grade11 = Hernandez_grade11['reading_score'].median()
MGriffin_grade11 = Griffin_grade11['reading_score'].median()
MWilson_grade11 = Wilson_grade11['reading_score'].median()
MCab_grade11 = Cab_grade11['reading_score'].median()
MBailey_grade11 = Bailey_grade11['reading_score'].median()
MHolden_grade11 = Holden_grade11['reading_score'].median()
MPena_grade11 = Pena_grade11['reading_score'].median()
MWright_grade11 = Wright_grade11['reading_score'].median()
MRod_grade11 = Rod_grade11['reading_score'].median()
MJohn_grade11 = John_grade11['reading_score'].median()
MFord_grade11 = Ford_grade11['reading_score'].median()
MThomas_grade11 = Thomas_grade11['reading_score'].median()

MHuang_grade12 = Huang_grade12['reading_score'].median()
MFig_grade12 = Fig_grade12['reading_score'].median()
MShelton_grade12 = Shelton_grade12['reading_score'].median()
MHernandez_grade12 = Hernandez_grade12['reading_score'].median()
MGriffin_grade12 = Griffin_grade12['reading_score'].median()
MWilson_grade12 = Wilson_grade12['reading_score'].median()
MCab_grade12 = Cab_grade12['reading_score'].median()
MBailey_grade12 = Bailey_grade12['reading_score'].median()
MHolden_grade12 = Holden_grade12['reading_score'].median()
MPena_grade12 = Pena_grade12['reading_score'].median()
MWright_grade12 = Wright_grade12['reading_score'].median()
MRod_grade12 = Rod_grade12['reading_score'].median()
MJohn_grade12 = John_grade12['reading_score'].median()
MFord_grade12 = Ford_grade12['reading_score'].median()
MThomas_grade12 = Thomas_grade12['reading_score'].median()

grade9 = [MHuang_grade9, MFig_grade9, MShelton_grade9, MHernandez_grade9, MGriffin_grade9, MWilson_grade9, MCab_grade9, MBailey_grade9, MHolden_grade9, MPena_grade9, MWright_grade9, MRod_grade9, MJohn_grade9, MFord_grade9, MThomas_grade9]
grade10 = [MHuang_grade10, MFig_grade10, MShelton_grade10, MHernandez_grade10, MGriffin_grade10, MWilson_grade10, MCab_grade10, MBailey_grade10, MHolden_grade10, MPena_grade10, MWright_grade10, MRod_grade10, MJohn_grade10, MFord_grade10, MThomas_grade10]
grade11 = [MHuang_grade11, MFig_grade11, MShelton_grade11, MHernandez_grade11, MGriffin_grade11, MWilson_grade11, MCab_grade11, MBailey_grade11, MHolden_grade11, MPena_grade11, MWright_grade11, MRod_grade11, MJohn_grade11, MFord_grade11, MThomas_grade11]
grade12 = [MHuang_grade12, MFig_grade12, MShelton_grade12, MHernandez_grade12, MGriffin_grade12, MWilson_grade12, MCab_grade12, MBailey_grade12, MHolden_grade12, MPena_grade12, MWright_grade12, MRod_grade12, MJohn_grade12, MFord_grade12, MThomas_grade12]


grade_df = pd.DataFrame({'School Name': ["Huang High School", "Figueroa High School", "Shelton High School", "Hernandez High School", "Griffin High School", "Wilson High School", "Cabrera High School", "Bailey High School", "Holden High School", "Pena High School", "Wright High School", "Rodriguez High School", "Johnson High School", "Ford High School", "Thomas High School"]})
grade_df["9th"] = grade9
grade_df["9th"] = grade_df["9th"].map("{:,.2f}".format)
grade_df["10th"] = grade10
grade_df["10th"] = grade_df["10th"].map("{:,.2f}".format)
grade_df["11th"] = grade11
grade_df["11th"] = grade_df["11th"].map("{:,.2f}".format)
grade_df["12th"] = grade12
grade_df["12th"] = grade_df["12th"].map("{:,.2f}".format)

grade_df
# Out:
#               School Name    9th   10th   11th   12th
# 0       Huang High School  82.00  82.00  82.00  80.00
# 1    Figueroa High School  81.00  82.00  81.00  82.00
# 2     Shelton High School  84.00  83.00  85.50  82.00
# 3   Hernandez High School  81.00  80.00  82.00  81.00
# 4     Griffin High School  83.00  84.00  84.00  84.00
# 5      Wilson High School  84.00  84.00  84.00  84.00
# 6     Cabrera High School  84.00  84.00  83.50  85.00
# 7      Bailey High School  82.00  81.00  81.00  81.00
# 8      Holden High School  83.00  84.00  84.00  85.00
# 9        Pena High School  84.00  84.00  84.00  85.00
# 10     Wright High School  84.00  84.00  85.00  84.00
# 11  Rodriguez High School  81.00  81.00  81.00  80.00
# 12    Johnson High School  81.00  81.00  80.00  81.00
# 13       Ford High School  81.00  82.00  81.00  81.00
# 14     Thomas High School  83.00  85.00  83.00  85.00

# %%
Data_frame = students_df[["school","grade","math_score"]]
rHuang_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Huang High School")]
#mHuang_grade9 = Huang_grade9.median()
rFig_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Figueroa High School")]
rShelton_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Shelton High School")]
rHernandez_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Hernandez High School")]
rGriffin_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Griffin High School")]
rWilson_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Wilson High School")]
rCab_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Cabrera High School")]
rBailey_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Bailey High School")]
rHolden_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Holden High School")]
rPena_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Pena High School")]
rWright_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Wright High School")]
rRod_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Rodriguez High School")]
rJohn_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Johnson High School")]
rFord_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Ford High School")]
rThomas_grade9 = Data_frame[(Data_frame["grade"] == "9th") & (Data_frame["school"] == "Thomas High School")]


rHuang_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Huang High School")]
rFig_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Figueroa High School")]
rShelton_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Shelton High School")]
rHernandez_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Hernandez High School")]
rGriffin_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Griffin High School")]
rWilson_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Wilson High School")]
rCab_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Cabrera High School")]
rBailey_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Bailey High School")]
rHolden_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Holden High School")]
rPena_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Pena High School")]
rWright_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Wright High School")]
rRod_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Rodriguez High School")]
rJohn_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Johnson High School")]
rFord_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Ford High School")]
rThomas_grade10 = Data_frame[(Data_frame["grade"] == "10th") & (Data_frame["school"] == "Thomas High School")]



rHuang_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Huang High School")]
rFig_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Figueroa High School")]
rShelton_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Shelton High School")]
rHernandez_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Hernandez High School")]
rGriffin_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Griffin High School")]
rWilson_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Wilson High School")]
rCab_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Cabrera High School")]
rBailey_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Bailey High School")]
rHolden_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Holden High School")]
rPena_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Pena High School")]
rWright_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Wright High School")]
rRod_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Rodriguez High School")]
rJohn_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Johnson High School")]
rFord_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Ford High School")]
rThomas_grade11 = Data_frame[(Data_frame["grade"] == "11th") & (Data_frame["school"] == "Thomas High School")]

rHuang_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Huang High School")]
rFig_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Figueroa High School")]
rShelton_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Shelton High School")]
rHernandez_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Hernandez High School")]
rGriffin_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Griffin High School")]
rWilson_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Wilson High School")]
rCab_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Cabrera High School")]
rBailey_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Bailey High School")]
rHolden_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Holden High School")]
rPena_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Pena High School")]
rWright_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Wright High School")]
rRod_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Rodriguez High School")]
rJohn_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Johnson High School")]
rFord_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Ford High School")]
rThomas_grade12 = Data_frame[(Data_frame["grade"] == "12th") & (Data_frame["school"] == "Thomas High School")]

#grade9 = [(Huang_grade9), Fig_grade9, Shelton_grade9, Hernandez_grade9, Griffin_grade9, Wilson_grade9, Cab_grade9, Bailey_grade9, Holden_grade9, Pena_grade9, Wright_grade9, Rod_grade9, John_grade9, Ford_grade9, Thomas_grade9]
rrHuang_grade9 = rHuang_grade9['math_score'].median()
rrFig_grade9 = rFig_grade9['math_score'].median()
rrShelton_grade9 = rShelton_grade9['math_score'].median()
rrHernandez_grade9 = rHernandez_grade9['math_score'].median()
rrGriffin_grade9 = rGriffin_grade9['math_score'].median()
rrWilson_grade9 = rWilson_grade9['math_score'].median()
rrCab_grade9 = rCab_grade9['math_score'].median()
rrBailey_grade9 = rBailey_grade9['math_score'].median()
rrHolden_grade9 = rHolden_grade9['math_score'].median()
rrPena_grade9 = rPena_grade9['math_score'].median()
rrWright_grade9 = rWright_grade9['math_score'].median()
rrRod_grade9 = rRod_grade9['math_score'].median()
rrJohn_grade9 = rJohn_grade9['math_score'].median()
rrFord_grade9 = rFord_grade9['math_score'].median()
rrThomas_grade9 = rThomas_grade9['math_score'].median()

rrHuang_grade10 = rHuang_grade10['math_score'].median()
rrFig_grade10 = rFig_grade10['math_score'].median()
rrShelton_grade10 = rShelton_grade10['math_score'].median()
rrHernandez_grade10 = rHernandez_grade10['math_score'].median()
rrGriffin_grade10 = rGriffin_grade10['math_score'].median()
rrWilson_grade10 = rWilson_grade10['math_score'].median()
rrCab_grade10 = rCab_grade10['math_score'].median()
rrBailey_grade10 = rBailey_grade10['math_score'].median()
rrHolden_grade10 = rHolden_grade10['math_score'].median()
rrPena_grade10 = rPena_grade10['math_score'].median()
rrWright_grade10 = rWright_grade10['math_score'].median()
rrRod_grade10 = rRod_grade10['math_score'].median()
rrJohn_grade10 = rJohn_grade10['math_score'].median()
rrFord_grade10 = rFord_grade10['math_score'].median()
rrThomas_grade10 = rThomas_grade10['math_score'].median()

rrHuang_grade11 = rHuang_grade11['math_score'].median()
rrFig_grade11 = rFig_grade11['math_score'].median()
rrShelton_grade11 = rShelton_grade11['math_score'].median()
rrHernandez_grade11 = rHernandez_grade11['math_score'].median()
rrGriffin_grade11 = rGriffin_grade11['math_score'].median()
rrWilson_grade11 = rWilson_grade11['math_score'].median()
rrCab_grade11 = rCab_grade11['math_score'].median()
rrBailey_grade11 = rBailey_grade11['math_score'].median()
rrHolden_grade11 = rHolden_grade11['math_score'].median()
rrPena_grade11 = rPena_grade11['math_score'].median()
rrWright_grade11 = rWright_grade11['math_score'].median()
rrRod_grade11 = rRod_grade11['math_score'].median()
rrJohn_grade11 = rJohn_grade11['math_score'].median()
rrFord_grade11 = rFord_grade11['math_score'].median()
rrThomas_grade11 = rThomas_grade11['math_score'].median()

rrHuang_grade12 = rHuang_grade12['math_score'].median()
rrFig_grade12 = rFig_grade12['math_score'].median()
rrShelton_grade12 = rShelton_grade12['math_score'].median()
rrHernandez_grade12 = rHernandez_grade12['math_score'].median()
rrGriffin_grade12 = rGriffin_grade12['math_score'].median()
rrWilson_grade12 = rWilson_grade12['math_score'].median()
rrCab_grade12 = rCab_grade12['math_score'].median()
rrBailey_grade12 = rBailey_grade12['math_score'].median()
rrHolden_grade12 = rHolden_grade12['math_score'].median()
rrPena_grade12 = rPena_grade12['math_score'].median()
rrWright_grade12 = rWright_grade12['math_score'].median()
rrRod_grade12 = rRod_grade12['math_score'].median()
rrJohn_grade12 = rJohn_grade12['math_score'].median()
rrFord_grade12 = rFord_grade12['math_score'].median()
rrThomas_grade12 = rThomas_grade12['math_score'].median()

rrgrade9 = [rrHuang_grade9, rrFig_grade9, rrShelton_grade9, rrHernandez_grade9, rrGriffin_grade9, rrWilson_grade9, rrCab_grade9, rrBailey_grade9, rrHolden_grade9, rrPena_grade9, rrWright_grade9, rrRod_grade9, rrJohn_grade9, rrFord_grade9, rrThomas_grade9]
rrgrade10 = [rrHuang_grade10, rrFig_grade10, rrShelton_grade10, rrHernandez_grade10, rrGriffin_grade10, rrWilson_grade10, rrCab_grade10, rrBailey_grade10, rrHolden_grade10, rrPena_grade10, rrWright_grade10, rrRod_grade10, rrJohn_grade10, rrFord_grade10, rrThomas_grade10]
rrgrade11 = [rrHuang_grade11, rrFig_grade11, rrShelton_grade11, rrHernandez_grade11, rrGriffin_grade11, rrWilson_grade11, rrCab_grade11, rrBailey_grade11, rrHolden_grade11, rrPena_grade11, rrWright_grade11, rrRod_grade11, rrJohn_grade11, rrFord_grade11, rrThomas_grade11]
rrgrade12 = [rrHuang_grade12, rrFig_grade12, rrShelton_grade12, rrHernandez_grade12, rrGriffin_grade12, rrWilson_grade12, rrCab_grade12, rrBailey_grade12, rrHolden_grade12, rrPena_grade12, rrWright_grade12, rrRod_grade12, rrJohn_grade12, rrFord_grade12, rrThomas_grade12]


rrgrade_df = pd.DataFrame({'School Name': ["Huang High School", "Figueroa High School", "Shelton High School", "Hernandez High School", "Griffin High School", "Wilson High School", "Cabrera High School", "Bailey High School", "Holden High School", "Pena High School", "Wright High School", "Rodriguez High School", "Johnson High School", "Ford High School", "Thomas High School"]})
rrgrade_df["9th"] = grade9
rrgrade_df["9th"] = rrgrade_df["9th"].map("{:,.2f}".format)
rrgrade_df["10th"] = grade10
rrgrade_df["10th"] = rrgrade_df["10th"].map("{:,.2f}".format)
rrgrade_df["11th"] = grade11
rrgrade_df["11th"] = rrgrade_df["11th"].map("{:,.2f}".format)
rrgrade_df["12th"] = grade12
rrgrade_df["12th"] = rrgrade_df["12th"].map("{:,.2f}".format)

rrgrade_df
# Out:
#               School Name    9th   10th   11th   12th
# 0       Huang High School  82.00  82.00  82.00  80.00
# 1    Figueroa High School  81.00  82.00  81.00  82.00
# 2     Shelton High School  84.00  83.00  85.50  82.00
# 3   Hernandez High School  81.00  80.00  82.00  81.00
# 4     Griffin High School  83.00  84.00  84.00  84.00
# 5      Wilson High School  84.00  84.00  84.00  84.00
# 6     Cabrera High School  84.00  84.00  83.50  85.00
# 7      Bailey High School  82.00  81.00  81.00  81.00
# 8      Holden High School  83.00  84.00  84.00  85.00
# 9        Pena High School  84.00  84.00  84.00  85.00
# 10     Wright High School  84.00  84.00  85.00  84.00
# 11  Rodriguez High School  81.00  81.00  81.00  80.00
# 12    Johnson High School  81.00  81.00  80.00  81.00
# 13       Ford High School  81.00  82.00  81.00  81.00
# 14     Thomas High School  83.00  85.00  83.00  85.00

# %%
school_spending = School_Summary
school_spending = school_spending.drop("School Type",1)
school_spending["Spending Per Student"] = school_spending['Total School Budget']/ school_spending['Total Students']
school_spending = school_spending.drop("Total Students",1)
school_spending = school_spending.drop("Total School Budget",1)
school_spending = school_spending.drop("Per Student Budget",1)
school_spending
# Out:
#               School Name Average Math Score Average Reading Score  \
# 0       Huang High School              76.63                 81.18
# 1    Figueroa High School              76.71                 81.16
# 2     Shelton High School              83.36                 83.73
# 3   Hernandez High School              77.29                 80.93
# 4     Griffin High School              83.35                 83.82
# 5      Wilson High School              83.27                 83.99
# 6     Cabrera High School              83.06                 83.98
# 7      Bailey High School              77.05                 81.03
# 8      Holden High School              83.80                 83.81
# 9        Pena High School              83.84                 84.04
# 10     Wright High School              83.68                 83.95
# 11  Rodriguez High School              76.84                 80.74
# 12    Johnson High School              77.07                 80.97
# ...

# %%
school_sizes = School_Summary
school_sizes
max = school_sizes["Total Students"].max()
max
min = school_sizes["Total Students"].min()
min
#bins = [0, 3500, 5000]
#bin_labels = ["Small",  "Medium", "Large"]
#school_sizes["Total Students"] = school_sizes["Total Students"]

#pd.cut(school_sizes['Total Students'], bins, labels=bin_labels)
def size(c):
    if c['Total Students'] <= 1000:
        return 'Small'
    elif 1000 < c['Total Students'] <= 3500:
        return 'Medium'
    elif 3500 < c['Total Students'] <= 5000:
        return 'Large'
    else:
        return 'Undefined'
school_sizes['Size'] = school_sizes.apply(size, axis=1)
school_sizes
# Out:
#               School Name School Type  Total Students  Total School Budget  \
# 0       Huang High School    District            2917              1910635
# 1    Figueroa High School    District            2949              1884411
# 2     Shelton High School     Charter            1761              1056600
# 3   Hernandez High School    District            4635              3022020
# 4     Griffin High School     Charter            1468               917500
# 5      Wilson High School     Charter            2283              1319574
# 6     Cabrera High School     Charter            1858              1081356
# 7      Bailey High School    District            4976              3124928
# 8      Holden High School     Charter             427               248087
# 9        Pena High School     Charter             962               585858
# 10     Wright High School     Charter            1800              1049400
# ...
